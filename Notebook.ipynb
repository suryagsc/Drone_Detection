# %%
mkdir Dlproject

# %%
cd Dlproject
# Out:
# [Errno 2] No such file or directory: 'Dlproject'
# /content/Dlproject

# %%
# !pip install unrar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !unrar x /content/Dlproject/BirdDatasetNew.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/Dlproject/BirdDatasetNew.rar
#
# Creating    Dataset                                                   OK
# Creating    Dataset/Images                                            OK
# Creating    Dataset/Images/Train                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !git clone git@github.com:ultralytics/yolov3.git
# Out:
# Cloning into 'yolov3'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git clone https://github.com/ultralytics/yolov3
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10065, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 10065 (delta 21), reused 28 (delta 13), pack-reused 10017
# Receiving objects: 100% (10065/10065), 9.38 MiB | 22.76 MiB/s, done.
# Resolving deltas: 100% (6779/6779), done.

# %%
# !cd yolov3

# %%
cd Dlproject/Dataset
# Out:
# /content/Dlproject/Dataset

# %%
cd yolov3
# Out:
# /content/Dlproject/yolov3

# %%
pwd
# Out:
# '/content/Dlproject/yolov3'

# %%
# !python train.py --img 640 --batch 16 --epochs 20 --data dataset.yaml --weights yolov3.pt
# Out:
# train: weights=yolov3.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov3 ✅
# YOLOv3 🚀 v9.6.0-29-ga441ab1 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --source runs/train/exp7/25eagles-web-superJumbo-2-_jpg.rf.d68c09c175338f27183a9cf803aaf1f3.jpg --weights runs/train/exp7/weights/best.pt
# Out:
# detect: weights=['runs/train/exp7/weights/best.pt'], source=runs/train/exp7/25eagles-web-superJumbo-2-_jpg.rf.d68c09c175338f27183a9cf803aaf1f3.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-29-ga441ab1 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61508200 parameters, 0 gradients
# image 1/1 /content/Dlproject/yolov3/runs/train/exp7/25eagles-web-superJumbo-2-_jpg.rf.d68c09c175338f27183a9cf803aaf1f3.jpg: 640x640 1 drone, 1 bird, Done. (0.065s)
# Speed: 0.6ms pre-process, 64.9ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3
